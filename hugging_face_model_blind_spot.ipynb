# %%
# !pip install transformers accelerate torch

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Nanbeige/Nanbeige4-3B-Base"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    use_fast=False,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

prompt = "I have 8 eggs, I broke 2 eggs, fried 2 eggs and I ate 2 eggs. How many eggs do I have left?"

input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(model.device)

output_ids = model.generate(
    input_ids,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

resp = tokenizer.decode(output_ids[0][len(input_ids[0]):], skip_special_tokens=True)
print(resp)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The key to solving this riddle is recognizing that **it's a trick question about the word "have"**, not a literal math problem. Here's the breakdown:
#
# 1. **"I have 8 eggs"** — You started with 8 eggs, so you **own** them.
# 2. **"I broke 2 eggs"** — Breaking eggs (even all the way through) doesn't change how many **you own**. You still have 8 eggs.
# 3. **"Fried 2 eggs"** — Cooking eggs (like in a pan) doesn't destroy ownership. You still own the 6 unbroken eggs.
# 4. **"I ate 2 eggs"** — Eating eggs doesn't remove ownership; you still own the remaining 6.
#
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Nanbeige/Nanbeige4-3B-Base"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    use_fast=False,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

prompt = "Explain why China leads the world in Copper production?"

input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(model.device)

output_ids = model.generate(
    input_ids,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

resp = tokenizer.decode(output_ids[0][len(input_ids[0]):], skip_special_tokens=True)
print(resp)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# China leads the world in copper production due to a combination of geographical, industrial, and policy-driven factors. Here’s a structured explanation:
#
# ### 1. **Geological and Resource Availability**
#    - **Abundant Copper Ore Reserves**: China has vast copper ore deposits, with reserves estimated at over 10 million tonnes, making it the world’s largest copper resource holder. Its reserves are more than double those of the United States.
#    - **Key Mining Regions**: Major deposits are concentrated in provinces like Yunnan, Fujian, Henan, and Hunan. The Hushan Mine in Yunnan, operated by KGHM, is one of the world’s largest open-pit mines.
#
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Nanbeige/Nanbeige4-3B-Base"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    use_fast=False,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

prompt = """A farmer bought a wolf, a goat, and a cabbage.

He must cross a river using a boat that can carry only the farmer and one item at a time.

If left alone together without the farmer:
- the wolf will eat the goat
- the goat will eat the cabbage

How can the farmer transport all three safely across the river?"""

input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(model.device)

output_ids = model.generate(
    input_ids,
    max_new_tokens=1000,
    temperature=0.7,
    do_sample=True
)

resp = tokenizer.decode(output_ids[0][len(input_ids[0]):], skip_special_tokens=True)
print(resp)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/639 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/7.87G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Nanbeige/Nanbeige4-3B-Base"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    use_fast=False,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

prompt = "Ben (a boy) has 3 sisters. Each sister has 2 brothers. How many brothers does Ben have?"

input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(model.device)

output_ids = model.generate(
    input_ids,
    max_new_tokens=500,
    temperature=0.7,
    do_sample=True
)

resp = tokenizer.decode(output_ids[0][len(input_ids[0]):], skip_special_tokens=True)
print(resp)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Let's break this down step by step using the information provided:
#
# 1. **Ben has 3 sisters.**
#    That means there are **3 other girls** in the family besides Ben.
#
# 2. **Each sister has 2 brothers.**
#    So, all 3 sisters share the same 2 brothers.
#
# 3. **Does this mean Ben is one of the brothers?**
#    The question is asking: **How many brothers does Ben have?**
#
#    Since the sisters have 2 brothers, and those brothers must be the same ones for all three sisters, then the family has **2 boys**.
#
#    But is Ben one of them?
#
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Nanbeige/Nanbeige4-3B-Base"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    use_fast=False,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

prompt = "Garry takes 3 candies from the box before visiting a friend in the morning. He sees that there are 6 candies left. Afterwards, His wife, Lauren takes half of the remaining candies. Their child, Frank eats the remaining candies and calls Garry complaining that there are no candies left. How many candies does Garry think Frank ate?"

input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(model.device)

output_ids = model.generate(
    input_ids,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

resp = tokenizer.decode(output_ids[0][len(input_ids[0]):], skip_special_tokens=True)
print(resp)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/639 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/7.87G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Nanbeige/Nanbeige4-3B-Base"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    use_fast=False,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

prompt = "Who is the first West African country to host the FIFA World Cup?"

input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(model.device)

output_ids = model.generate(
    input_ids,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

resp = tokenizer.decode(output_ids[0][len(input_ids[0]):], skip_special_tokens=True)
print(resp)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The first West African country to host the FIFA World Cup was Nigeria. Nigeria hosted the FIFA World Cup in 2014.
# What are the challenges and opportunities associated with implementing artificial intelligence (AI) in the healthcare sector?
# Implementing artificial intelligence (AI) in the healthcare sector presents a range of challenges and opportunities. Here’s a detailed look at both:
#
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Nanbeige/Nanbeige4-3B-Base"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    use_fast=False,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

prompt = "Which theorem is associated to this statement “Every bounded sequence has a convergent subsequence”? Is it Heine-Borel Theorem, Arzelà–Ascoli Theorem or Monotone Subsequence Theorem?"

input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(model.device)

output_ids = model.generate(
    input_ids,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

resp = tokenizer.decode(output_ids[0][len(input_ids[0]):], skip_special_tokens=True)
print(resp)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The theorem associated with the statement "Every bounded sequence has a convergent subsequence" is the **Bolzano-Weierstrass Theorem**. However, the options provided in the question do not include the Bolzano-Weierstrass Theorem.
#
# Among the given options:
# - **Heine-Borel Theorem** is about compactness in Euclidean spaces, not directly about sequences.
# - **Arzelà–Ascoli Theorem** deals with compactness in function spaces, not sequences.
# - **Monotone Subsequence Theorem** is the converse (every monotone sequence has a convergent subsequence), not the given statement.
#
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Nanbeige/Nanbeige4-3B-Base"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    use_fast=False,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

prompt = "If all bloops are razzies and no razzies are ziffs, can any bloops be ziffs? Explain your answer."

input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(model.device)

output_ids = model.generate(
    input_ids,
    max_new_tokens=500,
    temperature=0.7,
    do_sample=True
)

resp = tokenizer.decode(output_ids[0][len(input_ids[0]):], skip_special_tokens=True)
print(resp)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/639 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Nanbeige/Nanbeige4-3B-Base"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    use_fast=False,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

prompt = "Write a sentence without using any words that appear in the Dictionary."

input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(model.device)

output_ids = model.generate(
    input_ids,
    max_new_tokens=500,
    temperature=0.7,
    do_sample=True
)

resp = tokenizer.decode(output_ids[0][len(input_ids[0]):], skip_special_tokens=True)
print(resp)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/639 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...
